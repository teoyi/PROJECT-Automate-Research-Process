# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import os
import os.path
from scipy.optimize import curve_fit

# %%
# # Loading file, and obtaining long name components 
# path = "./updated_test/995/202_p20_n1_x_100_IT_10_A.csv"
# df = pd.read_csv(path)
# df = df.drop(index=0)
# df = df.astype('float64')
# df['S2'] = df['S2']*1000 
# df['S2c'] = df['S2c']*1000
# plt.plot(df['Wavelength'], df['S2'], label='S2', color='red')
# plt.plot(df['Wavelength'], df['S2c'], label='S2c', color = 'black')
# plt.xlabel('Wavelength (nm)')
# plt.ylabel('Emission Intensity (mV)')
# plt.legend()
# plt.savefig('s2compare.png', bbox_inches='tight')
# plt.show()

# %%
# For 843 
path1 = "./updated_test/843/202_n10_n1_x_100_10_IT_10_A.csv"
path2 = "./updated_test/843/202_n10_n1_x_100_10_IT_10_B.csv"
path3 = "./updated_test/843/202_n10_n1_x_100_10_IT_10_C.csv"
path4 = "./updated_test/843/202_n10_n1_x_100_10_IT_10_D.csv"
finalpath = "./updated_test/843/final_data/202_n10_n1_x_100_10_IT_10"

df1 = pd.read_csv(path1)
df1 = df1.drop(index=0)
df1 = df1.astype('float64')

df2 = pd.read_csv(path2)
df2 = df2.drop(index=0)
df2 = df2.astype('float64')

df3 = pd.read_csv(path3)
df3 = df3.drop(index=0)
df3 = df3.astype('float64')

df4 = pd.read_csv(path4)
df4 = df4.drop(index=0)
df4 = df4.astype('float64')

df_final = pd.read_csv(finalpath)
df_final = df_final.drop(index=0)
df_final = df_final.astype('float64')

plt.figure()
plt.plot(df1['Wavelength'],df1['S2c'], color='red' , zorder=1, label='First Run')
plt.plot(df2['Wavelength'],df2['S2c'], color='blue', zorder=1, label='Second Run')
plt.plot(df3['Wavelength'],df3['S2c'], color='green', zorder=1, label='Third Run')
plt.plot(df4['Wavelength'],df4['S2c'], color='purple',zorder=1, label='Fourth Run')
plt.scatter(df_final['Wavelength'],df_final['S2c'], color='black', zorder=0, s=15, marker="^", label='Compiled')
plt.legend(frameon=False)
plt.xlabel("Wavelength (nm)")
plt.ylabel("Emission Intensity (V)")
plt.savefig('843compiled.png', bbox_inches='tight')
plt.show()

# %%
print(df_final)
# Out:
#      Wavelength       S2c  Wavelength.1        S2
# 1        1110.0  0.001165        1110.0  0.001055
# 2        1120.0  0.001002        1120.0  0.000919
# 3        1130.0  0.001004        1130.0  0.000932
# 4        1140.0  0.001081        1140.0  0.001011
# 5        1150.0  0.001081        1150.0  0.001017
# ..          ...       ...           ...       ...
# 200      1460.0  0.006153        1460.0  0.005146
# 201      1470.0  0.006315        1470.0  0.005179
# 202      1480.0  0.006977        1480.0  0.005602
# 203      1490.0  0.007664        1490.0  0.006019
# 204      1500.0  0.008424        1500.0  0.006473
#
# [204 rows x 4 columns]

# %%
# # For 995 
# path1 = "./updated_test/995/202_p16_n1_x_100_IT_10_A.csv"
# path2 = "./updated_test/995/202_p16_n1_x_100_IT_10_B.csv"
# path3 = "./updated_test/995/202_p16_n1_x_100_IT_10_C.csv"
# path4 = "./updated_test/995/202_p16_n1_x_100_IT_10_D.csv"
# path5 = "./updated_test/995/202_p16_n1_x_100_IT_10_E.csv"
# finalpath = "./updated_test/995/final_data/202_p16_n1_x_100_IT_10"

# df1 = pd.read_csv(path1)
# df1 = df1.drop(index=0)
# df1 = df1.astype('float64')

# df2 = pd.read_csv(path2)
# df2 = df2.drop(index=0)
# df2 = df2.astype('float64')

# df3 = pd.read_csv(path3)
# df3 = df3.drop(index=0)
# df3 = df3.astype('float64')

# df4 = pd.read_csv(path4)
# df4 = df4.drop(index=0)
# df4 = df4.astype('float64')

# df5 = pd.read_csv(path5)
# df5 = df5.drop(index=0)
# df5 = df5.astype('float64')

# df_final = pd.read_csv(finalpath)
# df_final = df_final.drop(index=0)
# df_final = df_final.astype('float64')

# plt.figure()
# plt.plot(df1['Wavelength'],df1['S2c'], color='red' , zorder=1, label='First Run')
# plt.plot(df2['Wavelength'],df2['S2c'], color='blue', zorder=1, label='Second Run')
# plt.plot(df3['Wavelength'],df3['S2c'], color='green', zorder=1, label='Third Run')
# plt.plot(df4['Wavelength'],df4['S2c'], color='purple',zorder=1, label='Fourth Run')
# plt.plot(df5['Wavelength'],df5['S2c'], color='purple',zorder=1, label='Fifth Run')
# plt.scatter(df_final['Wavelength'],df_final['S2c'], color='black', zorder=0, s=15, marker="^", label='Compiled')
# plt.legend(frameon=False)
# plt.xlabel("Wavelength (nm)")
# plt.ylabel("Emission Intensity (V)")
# plt.savefig('995compiled.png', bbox_inches='tight')
# plt.show()
